# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:46, 295KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
len(text)
# Out:
# 100000000

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(int_words[0])
print(vocab_to_int['the'])
print(int_to_vocab[5243])
# Out:
# 5237
# 0
# belonging

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import random
from collections import Counter

# %%
## Your code here
threshold = 1e-5
word_count = Counter()
prob_drop = {}
total_count = len(int_words)

for i in int_words:
    word_count[i] += 1
    
for i in word_count:
    prob_drop[i] = 1 - ((threshold / (word_count[i] / total_count))**0.5)

train_words = [word for word in int_words if random.random() < (1 - prob_drop[word])] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = np.random.randint(1, window_size+1)
    start = idx - r if idx > r else 0
    stop = idx + r + 1
    targets = set(words[start:idx] + words[idx+1:stop])
    
    return targets

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape = (None), name = 'inputs')
    labels = tf.placeholder(tf.int32, shape = (None, None), name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev = 0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6420 0.0861 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6312 0.0813 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5181 0.0813 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5977 0.0809 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4998 0.0810 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5329 0.0810 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5495 0.0814 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5419 0.0833 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4822 0.0846 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4189 0.0853 sec/batch
# Nearest to such: clare, proverbial, verrocchio, consent, cyclic, ccd, hayden, randal,
# Nearest to eight: seized, interventionist, grievances, kamchatka, upwards, terrier, perfective, barbarians,
# Nearest to at: namo, stoa, purified, creeds, inimical, topmost, suspicion, exploits,
# Nearest to zero: slovakia, eines, performs, crown, islands, strangled, extradited, tram,
# Nearest to from: champagne, doraemon, bava, privileges, linearity, bearers, recoiled, makes,
# Nearest to than: overgrowth, ua, escu, counterweight, extents, inker, walt, anas,
# Nearest to some: unsettling, noticeable, percent, ratchet, milli, ropes, kicks, onside,
# Nearest to system: parthians, decker, cournot, burleigh, mutable, ephraim, zero, amaranth,
# Nearest to egypt: imparts, motherland, stabat, franchising, devonport, retrograde, hasidim, windshield,
# Nearest to recorded: protagonists, dystopian, realized, handfasting, timestamp, sickness, imparts, messe,
# Nearest to paris: dispositions, recoil, suborder, quoque, unwinding, impregnated, devastation, hasn,
# Nearest to magazine: demonstrator, elective, bern, muds, forego, mp, foggy, copied,
# Nearest to powers: mea, nihilo, negotiable, mediocre, linguistique, lahore, chandra, rests,
# Nearest to square: coe, pv, dehydration, encrypt, respective, afghana, annoyed, hersh,
# Nearest to bbc: francks, cluniac, horseman, henrik, manipulation, weightlessness, deterrence, jarama,
# Nearest to road: ure, chaitin, condensing, orientalist, schell, wouldn, warwickshire, ig,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5007 0.0870 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3929 0.0866 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3667 0.0881 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2467 0.0893 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1816 0.0891 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1712 0.0883 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1305 0.0894 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0723 0.0903 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0103 0.0889 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9994 0.0898 sec/batch
# Nearest to such: have, cyclic, consent, pp, clare, data, concepts, hayden,
# Nearest to eight: seized, upwards, interventionist, barbarians, grievances, store, up, terrier,
# Nearest to at: suspicion, spine, objectors, anything, diacritic, laughter, inimical, pit,
# Nearest to zero: slovakia, crown, islands, three, eines, performs, communities, concepts,
# Nearest to from: champagne, doraemon, privileges, makes, obtained, italy, specialists, taxonomic,
# Nearest to than: focus, walt, overgrowth, inker, ua, extents, nonkinetochore, lackluster,
# Nearest to some: noticeable, percent, through, equal, torgau, manufacturers, kicks, drawer,
# Nearest to system: types, another, parthians, decker, only, mild, burleigh, cournot,
# Nearest to egypt: imparts, motherland, trends, ordered, windshield, stabat, franchising, censuses,
# Nearest to recorded: protagonists, dystopian, realized, handfasting, imparts, sickness, messe, mudd,
# Nearest to paris: recoil, dispositions, hasn, scientifically, unwinding, called, vital, covers,
# Nearest to magazine: demonstrator, mp, resulting, muds, media, copied, elective, shorts,
# Nearest to powers: books, mea, linguistique, lahore, rests, nihilo, mediocre, negotiable,
# Nearest to square: coe, respective, dehydration, encrypt, substantial, pv, yahoo, including,
# Nearest to bbc: francks, cluniac, manipulation, be, approximately, henrik, horseman, ng,
# Nearest to road: occurred, schell, wouldn, ure, warwickshire, need, riff, orientalist,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9503 0.0916 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9244 0.0901 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8836 0.0911 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8647 0.0912 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8204 0.0903 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8089 0.0902 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7945 0.0903 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8082 0.0900 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7968 0.0904 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7913 0.0911 sec/batch
# Nearest to such: consent, cyclic, converges, pp, concepts, have, sufficiency, masses,
# Nearest to eight: seized, upwards, barbarians, precocious, interventionist, sheltered, grievances, crimean,
# Nearest to at: suspicion, namo, consortium, objectors, spine, waterfall, css, laughter,
# Nearest to zero: three, eines, crown, slovakia, five, islands, km, communities,
# Nearest to from: privileges, champagne, doraemon, makes, belong, obtained, taxonomic, ore,
# Nearest to than: ua, focus, overgrowth, walt, inker, lackluster, extents, gust,
# Nearest to some: noticeable, percent, through, populate, torgau, unsettling, ratchet, kicks,
# Nearest to system: types, yugoslavia, decker, parthians, architectural, mild, realist, loire,
# Nearest to egypt: motherland, imparts, negotiations, franchising, trends, windshield, ordered, vincent,
# Nearest to recorded: protagonists, realized, dystopian, sickness, mudd, imparts, messe, aimed,
# Nearest to paris: dispositions, recoil, scientifically, hasn, vital, netherlands, banished, unwinding,
# Nearest to magazine: mp, demonstrator, bern, muds, resulting, copied, deteriorated, moisture,
# Nearest to powers: linguistique, books, rests, mea, socialist, massachusetts, glass, wannsee,
# Nearest to square: coe, respective, encrypt, pv, annoyed, dehydration, combat, yahoo,
# Nearest to bbc: francks, manipulation, horseman, henrik, corrected, cluniac, approximately, ng,
# Nearest to road: wouldn, occurred, ure, orientalist, warwickshire, schell, riff, need,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7870 0.0915 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7660 0.0944 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7253 0.0919 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6777 0.0917 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7420 0.0920 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6816 0.0916 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7029 0.0920 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7144 0.0923 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7158 0.0912 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6702 0.0909 sec/batch
# Nearest to such: consent, converges, cyclic, sufficiency, have, artifact, concepts, masses,
# Nearest to eight: pianist, seized, one, enrich, three, barbarians, sheltered, five,
# Nearest to at: objectors, css, namo, consortium, laughter, topmost, exploits, suspicion,
# Nearest to zero: three, five, four, km, eines, six, islands, strangled,
# Nearest to from: privileges, champagne, doraemon, recoiled, makes, drifting, reverend, assemblies,
# Nearest to than: ua, overgrowth, inker, lackluster, focus, walt, horns, specializes,
# Nearest to some: noticeable, populate, percent, through, unsettling, torgau, prolog, ratchet,
# Nearest to system: types, decker, mild, parthians, nonempty, yugoslavia, architectural, loire,
# Nearest to egypt: motherland, imparts, negotiations, franchising, vincent, stabat, censuses, claimed,
# Nearest to recorded: protagonists, dystopian, mudd, realized, sickness, imparts, messe, handfasting,
# Nearest to paris: dispositions, recoil, vital, hasn, banished, suborder, scientifically, unwinding,
# Nearest to magazine: demonstrator, elective, muds, bern, mp, deteriorated, forego, patti,
# Nearest to powers: linguistique, rests, mea, lahore, negotiable, mediocre, socialist, massachusetts,
# Nearest to square: coe, respective, annoyed, pv, avengers, encrypt, dehydration, meadows,
# Nearest to bbc: manipulation, francks, horseman, conversations, henrik, deterrence, cluniac, biologists,
# Nearest to road: ure, wouldn, orientalist, riff, warwickshire, investigates, ig, occurred,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6704 0.0917 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6641 0.0911 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6252 0.0918 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6389 0.0912 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6331 0.0910 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6271 0.0910 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5944 0.0678 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5416 0.0909 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5290 0.0908 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5106 0.0905 sec/batch
# Nearest to such: consent, converges, sufficiency, concepts, data, cyclic, have, artifact,
# Nearest to eight: pianist, one, three, philanthropist, five, four, scientist, seized,
# Nearest to at: objectors, css, exploits, ayya, laughter, topmost, concordant, namo,
# Nearest to zero: three, five, four, two, km, six, islands, eines,
# Nearest to from: champagne, doraemon, privileges, recoiled, makes, drifting, specialists, optimisation,
# Nearest to than: ua, overgrowth, horns, inker, lackluster, focus, counterweight, specializes,
# Nearest to some: noticeable, populate, percent, through, unnatural, unsettling, prolog, onside,
# Nearest to system: types, nonempty, architectural, mild, decker, ietf, generalizations, analyzer,
# Nearest to egypt: motherland, stabat, censuses, imparts, fundamentalists, bordered, franchising, negotiations,
# Nearest to recorded: protagonists, dystopian, messe, mudd, sickness, imparts, realized, ozark,
# Nearest to paris: dispositions, banished, unwinding, hasn, netherlands, uneconomic, cassius, suborder,
# Nearest to magazine: demonstrator, foggy, bern, muds, deteriorated, elective, mp, forego,
# Nearest to powers: linguistique, rests, mea, negotiable, lahore, mediocre, wannsee, chandra,
# Nearest to square: coe, annoyed, avengers, respective, pv, encrypt, capitulate, accelerate,
# Nearest to bbc: manipulation, henrik, francks, horseman, conversations, deterrence, cluniac, ng,
# Nearest to road: wouldn, ure, riff, americanized, investigates, orientalist, warwickshire, cemetery,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4954 0.0917 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4968 0.0906 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4811 0.0912 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5051 0.0908 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5180 0.0912 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4842 0.0915 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4425 0.0917 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4177 0.0920 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4593 0.0923 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4326 0.0927 sec/batch
# Nearest to such: concepts, converges, cyclic, consent, sufficiency, artifact, data, have,
# Nearest to eight: three, philanthropist, one, pianist, seized, five, crimean, precocious,
# Nearest to at: objectors, css, concordant, ayya, laughter, spine, purified, exploits,
# Nearest to zero: three, five, two, km, four, six, islands, phosphates,
# Nearest to from: makes, specialists, optimisation, doraemon, recoiled, champagne, taxonomic, linearity,
# Nearest to than: ua, overgrowth, focus, lackluster, nutritional, kcal, counterweight, horns,
# Nearest to some: noticeable, unsettling, populate, percent, through, prolog, unnatural, ratchet,
# Nearest to system: nonempty, types, ietf, decker, mild, architectural, analyzer, generalizations,
# Nearest to egypt: bordered, negotiations, motherland, stabat, fundamentalists, devonport, gerardo, censuses,
# Nearest to recorded: protagonists, dystopian, mudd, messe, sickness, handfasting, nails, imparts,
# Nearest to paris: banished, dispositions, uneconomic, cassius, netherlands, unwinding, hasn, suborder,
# Nearest to magazine: demonstrator, foggy, muds, deteriorated, bern, forego, mp, elective,
# Nearest to powers: mea, rests, socialist, mediocre, linguistique, lahore, negotiable, chandra,
# Nearest to square: coe, annoyed, avengers, pv, capitulate, modernisation, combat, respective,
# Nearest to bbc: francks, henrik, manipulation, horseman, conversations, ng, cluniac, deterrence,
# Nearest to road: wouldn, ure, riff, cemetery, investigates, warwickshire, americanized, stopwatch,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4669 0.0943 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4168 0.0931 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4507 0.0929 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4137 0.0924 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4142 0.0916 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4719 0.0917 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3605 0.0912 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3867 0.0923 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4347 0.0923 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3844 0.0914 sec/batch
# Nearest to such: concepts, consent, converges, replicating, cyclic, sufficiency, data, artifact,
# Nearest to eight: one, three, five, pianist, philanthropist, four, seized, zero,
# Nearest to at: objectors, concordant, css, feathers, topmost, laughter, prenatal, purified,
# Nearest to zero: three, five, two, four, six, km, phosphates, eight,
# Nearest to from: makes, specialists, champagne, recoiled, optimisation, assemblies, doraemon, drifting,
# Nearest to than: overgrowth, ua, focus, counterweight, lackluster, horns, kcal, nutritional,
# Nearest to some: noticeable, percent, prolog, populate, onside, unsettling, through, unnatural,
# Nearest to system: types, ietf, nonempty, decker, analyzer, architectural, mild, generalizations,
# Nearest to egypt: bordered, seizes, negotiations, fundamentalists, gerardo, stabat, ptolemaic, devonport,
# Nearest to recorded: protagonists, dystopian, messe, mudd, nails, imparts, sickness, tyne,
# Nearest to paris: netherlands, dispositions, cassius, banished, uneconomic, july, acclaim, phraseology,
# Nearest to magazine: foggy, demonstrator, patti, deteriorated, muds, forego, mp, clef,
# Nearest to powers: rests, mea, socialist, lahore, linguistique, negotiable, mediocre, chandra,
# Nearest to square: coe, avengers, modernisation, pv, annoyed, combat, diagonal, accelerate,
# Nearest to bbc: francks, henrik, manipulation, conversations, horseman, deterrence, ng, throwback,
# Nearest to road: wouldn, ure, americanized, stopwatch, warwickshire, cemetery, riff, investigates,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3707 0.0925 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3767 0.0911 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3606 0.0913 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3629 0.0912 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4096 0.0920 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3840 0.0934 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3789 0.0917 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3844 0.0924 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3590 0.0927 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3506 0.0924 sec/batch
# Nearest to such: concepts, converges, verrocchio, consent, replicating, cyclic, sufficiency, purely,
# Nearest to eight: three, one, five, four, seized, zero, pianist, upwards,
# Nearest to at: css, objectors, concordant, feathers, topmost, spine, silvery, unquestioning,
# Nearest to zero: five, three, two, four, six, eight, km, est,
# Nearest to from: specialists, drifting, champagne, makes, disciplining, privileges, doraemon, recoiled,
# Nearest to than: overgrowth, ua, kcal, lackluster, counterweight, focus, horns, gust,
# Nearest to some: percent, noticeable, populate, onside, through, unsettling, prolog, unnatural,
# Nearest to system: ietf, decker, nonempty, types, analyzer, architectural, drenched, mild,
# Nearest to egypt: bordered, stabat, fundamentalists, negotiations, seizes, annexed, gerardo, ptolemaic,
# Nearest to recorded: dystopian, protagonists, messe, mudd, nails, imparts, felis, sediments,
# Nearest to paris: banished, uneconomic, netherlands, cassius, phraseology, dispositions, july, quoque,
# Nearest to magazine: muds, patti, foggy, demonstrator, clef, xnor, forego, bern,
# Nearest to powers: socialist, rests, mea, lahore, fukuyama, gaul, quo, linguistique,
# Nearest to square: coe, avengers, km, accelerate, spans, mathrm, capitulate, paradigmatic,
# Nearest to bbc: francks, henrik, manipulation, conversations, deterrence, horseman, throwback, corrected,
# Nearest to road: americanized, wouldn, stopwatch, warwickshire, cemetery, ure, phoebus, investigates,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3374 0.0939 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2748 0.0926 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3553 0.0918 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3734 0.0920 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3971 0.0914 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3059 0.0911 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3037 0.0912 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3421 0.0923 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2358 0.0924 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3192 0.0916 sec/batch
# Nearest to such: concepts, verrocchio, converges, consent, artifact, sufficiency, replicating, cock,
# Nearest to eight: one, three, five, zero, four, pianist, six, philanthropist,
# Nearest to at: css, fraser, concordant, objectors, feathers, topmost, pennock, hiram,
# Nearest to zero: five, three, two, four, six, est, eight, phosphates,
# Nearest to from: drifting, makes, champagne, recoiled, disciplining, specialists, merge, doraemon,
# Nearest to than: overgrowth, counterweight, lackluster, ua, focus, kcal, horns, marginalization,
# Nearest to some: prolog, noticeable, percent, onside, populate, unnatural, unsettling, setbacks,
# Nearest to system: ietf, nonempty, decker, emulation, analyzer, types, mild, architectural,
# Nearest to egypt: bordered, stabat, fundamentalists, ordered, negotiations, seizes, ptolemaic, annexed,
# Nearest to recorded: protagonists, dystopian, nails, messe, mudd, felis, tyne, ozark,
# Nearest to paris: uneconomic, banished, netherlands, cassius, quoque, plh, vital, polonaise,
# Nearest to magazine: patti, muds, foggy, clef, jermaine, nominee, forego, demonstrator,
# Nearest to powers: rests, mea, socialist, fukuyama, lahore, quo, linguistique, organise,
# Nearest to square: coe, accelerate, diagonal, km, avengers, mathrm, spans, covers,
# Nearest to bbc: francks, henrik, conversations, manipulation, deterrence, ng, throwback, cheryl,
# Nearest to road: americanized, stopwatch, wouldn, ure, warwickshire, phoebus, cemetery, riff,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2987 0.0926 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2916 0.0913 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3461 0.0446 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2687 0.0918 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2158 0.0932 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2110 0.0920 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2060 0.0909 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2006 0.0906 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2251 0.0912 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1790 0.0942 sec/batch
# Nearest to such: verrocchio, concepts, consent, cock, replicating, artifact, converges, purely,
# Nearest to eight: three, one, five, zero, six, four, seized, pianist,
# Nearest to at: css, concordant, spine, fraser, waterfall, unquestioning, pennock, mastiff,
# Nearest to zero: five, three, two, four, six, phosphates, eight, est,
# Nearest to from: drifting, merge, champagne, recoiled, disciplining, makes, specialists, doraemon,
# Nearest to than: overgrowth, counterweight, focus, lackluster, horns, ua, kcal, purley,
# Nearest to some: noticeable, prolog, onside, percent, populate, unnatural, unsettling, repetitions,
# Nearest to system: ietf, branch, architectural, nonempty, decker, analyzer, emulation, macsyma,
# Nearest to egypt: bordered, ptolemaic, ordered, stabat, fundamentalists, annexed, motherland, seizes,
# Nearest to recorded: dystopian, protagonists, nails, messe, mudd, felis, vodun, ozark,
# Nearest to paris: banished, uneconomic, quoque, netherlands, cassius, plh, vital, polonaise,
# Nearest to magazine: muds, patti, clef, forego, foggy, nominee, mp, jermaine,
# Nearest to powers: rests, mea, socialist, fukuyama, lahore, organise, vaginal, linguistique,
# Nearest to square: coe, mathrm, km, meadows, spans, accelerate, diagonal, avengers,
# Nearest to bbc: francks, henrik, manipulation, ng, deterrence, conversations, throwback, corrected,
# Nearest to road: americanized, stopwatch, highway, rail, warwickshire, chinatown, wouldn, phoebus,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2409 0.0939 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2265 0.0926 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1993 0.0924 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1375 0.0929 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1825 0.0936 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1770 0.0945 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1663 0.0933 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1848 0.0924 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1978 0.0924 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1887 0.0927 sec/batch
# Nearest to such: concepts, verrocchio, cock, consent, replicating, artifact, sufficiency, converges,
# Nearest to eight: five, three, one, zero, six, four, seized, guadeloupe,
# Nearest to at: css, concordant, mastiff, unquestioning, pennock, waterfall, objectors, hiram,
# Nearest to zero: five, two, three, four, six, eight, est, one,
# Nearest to from: drifting, makes, doraemon, recoiled, specialists, champagne, merge, optimisation,
# Nearest to than: overgrowth, counterweight, horns, kcal, subsided, lackluster, ua, purley,
# Nearest to some: onside, noticeable, unnatural, prolog, percent, unsettling, populate, promote,
# Nearest to system: ietf, architectural, branch, decker, analyzer, nonempty, holders, emulation,
# Nearest to egypt: bordered, ptolemaic, stabat, fundamentalists, ordered, seizes, annexed, monotheists,
# Nearest to recorded: dystopian, protagonists, nails, messe, mudd, vodun, ozark, bebop,
# Nearest to paris: banished, netherlands, uneconomic, quoque, cassius, plh, polonaise, bian,
# Nearest to magazine: muds, forego, patti, nominee, clef, deteriorated, mp, demonstrator,
# Nearest to powers: rests, mea, socialist, fukuyama, lahore, organise, vaginal, depraved,
# Nearest to square: mathrm, km, spans, diagonal, coe, covers, meadows, foreground,
# Nearest to bbc: francks, manipulation, henrik, ng, conversations, deterrence, throwback, radio,
# Nearest to road: americanized, chinatown, highway, rail, cemetery, completed, warwickshire, stopwatch,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1800 0.0925 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2186 0.0910 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1644 0.0913 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1657 0.0921 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1757 0.0931 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2027 0.0921 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2108 0.0915 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1698 0.0910 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1301 0.0914 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1677 0.0916 sec/batch
# Nearest to such: concepts, verrocchio, replicating, converges, purely, consent, cock, artifact,
# Nearest to eight: three, five, one, six, zero, four, two, seized,
# Nearest to at: concordant, css, unquestioning, manco, mastiff, hiram, spine, objectors,
# Nearest to zero: five, two, three, four, six, eight, est, total,
# Nearest to from: drifting, makes, aziz, doraemon, champagne, merge, passos, specialists,
# Nearest to than: overgrowth, counterweight, kcal, horns, subsided, distinctions, ua, focus,
# Nearest to some: onside, noticeable, unnatural, prolog, unsettling, repetitions, promote, carolingian,
# Nearest to system: ietf, analyzer, branch, holders, architectural, emulation, macsyma, decker,
# Nearest to egypt: bordered, ptolemaic, ordered, stabat, fundamentalists, seizes, annexed, motherland,
# Nearest to recorded: dystopian, protagonists, nails, messe, mudd, vodun, felis, ozark,
# Nearest to paris: banished, uneconomic, polonaise, quoque, netherlands, plh, doosra, bian,
# Nearest to magazine: muds, patti, forego, nominee, mp, clef, competitor, mrl,
# Nearest to powers: rests, vaginal, fukuyama, mea, lahore, socialist, organise, depraved,
# Nearest to square: mathrm, diagonal, km, meadows, accelerate, coe, spans, covers,
# Nearest to bbc: francks, manipulation, henrik, conversations, throwback, corrected, ng, cheryl,
# Nearest to road: highway, americanized, stopwatch, phoebus, chinatown, rail, completed, warwickshire,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1984 0.0924 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1586 0.0910 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1865 0.0912 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1913 0.0920 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1539 0.0924 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1148 0.0918 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1677 0.0928 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1250 0.0922 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1861 0.0919 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1942 0.0914 sec/batch
# Nearest to such: concepts, verrocchio, consent, purely, replicating, cock, wane, converges,
# Nearest to eight: one, three, five, four, six, zero, two, philanthropist,
# Nearest to at: concordant, hiram, css, objectors, pennock, fraser, manco, mastiff,
# Nearest to zero: five, two, three, four, six, eight, one, nine,
# Nearest to from: drifting, disciplining, aziz, makes, scone, champagne, passos, prague,
# Nearest to than: overgrowth, counterweight, subsided, kcal, ua, incomes, lackluster, horns,
# Nearest to some: onside, unnatural, noticeable, repetitions, percent, prolog, carolingian, promote,
# Nearest to system: ietf, branch, holders, decker, architectural, analyzer, mild, macsyma,
# Nearest to egypt: bordered, ptolemaic, ordered, fundamentalists, stabat, seizes, claimed, vindhya,
# Nearest to recorded: dystopian, nails, protagonists, vodun, messe, mudd, ozark, lincom,
# Nearest to paris: banished, netherlands, quoque, uneconomic, entered, plh, bian, polonaise,
# Nearest to magazine: muds, patti, nominee, forego, puts, mrl, foster, demonstrator,
# Nearest to powers: rests, vaginal, mea, fukuyama, lahore, depraved, socialist, organise,
# Nearest to square: mathrm, meadows, km, diagonal, coe, spans, covers, capitulate,
# Nearest to bbc: francks, manipulation, corrected, henrik, conversations, ng, bhangra, cheryl,
# Nearest to road: highway, americanized, phoebus, chinatown, stopwatch, rail, warwickshire, cemetery,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2421 0.0928 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1335 0.0913 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1551 0.0911 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1584 0.0911 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0322 0.0913 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1344 0.0918 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1510 0.0915 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1621 0.0911 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1759 0.0206 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1186 0.0917 sec/batch
# Nearest to such: concepts, verrocchio, cock, consent, purely, wane, converges, replicating,
# Nearest to eight: three, five, one, four, zero, six, two, cray,
# Nearest to at: pennock, hiram, concordant, lowers, manco, css, princeton, spine,
# Nearest to zero: two, five, three, four, six, eight, one, est,
# Nearest to from: drifting, disciplining, the, makes, aziz, cimmeria, merge, hiker,
# Nearest to than: counterweight, overgrowth, subsided, incomes, kcal, purley, ua, distinctions,
# Nearest to some: onside, prolog, unnatural, noticeable, landscapes, repetitions, ensures, percent,
# Nearest to system: branch, ietf, architectural, emulation, macsyma, analyzer, combinatory, holders,
# Nearest to egypt: bordered, ptolemaic, stabat, fundamentalists, ordered, arabian, vindhya, seizes,
# Nearest to recorded: nails, dystopian, protagonists, messe, ozark, felis, vodun, lincom,
# Nearest to paris: banished, quoque, uneconomic, netherlands, vital, polonaise, entered, plh,
# Nearest to magazine: muds, patti, forego, puts, archive, mrl, nominee, mp,
# Nearest to powers: rests, vaginal, mea, fukuyama, depraved, organise, lahore, wannsee,
# Nearest to square: mathrm, diagonal, covers, meadows, spans, foreground, km, coe,
# Nearest to bbc: francks, manipulation, corrected, henrik, conversations, bhangra, radio, cheryl,
# Nearest to road: highway, americanized, chinatown, rail, stopwatch, phoebus, wouldn, completed,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0804 0.0925 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0736 0.0906 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0793 0.0912 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0505 0.0910 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0665 0.0919 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0552 0.0908 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0862 0.0915 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1073 0.0911 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1097 0.0916 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0138 0.0920 sec/batch
# Nearest to such: concepts, verrocchio, consent, purely, cock, replicating, ccd, wane,
# Nearest to eight: three, five, one, six, four, zero, two, seized,
# Nearest to at: lowers, concordant, hiram, unquestioning, spine, manco, pennock, mastiff,
# Nearest to zero: five, two, three, six, four, eight, one, est,
# Nearest to from: drifting, the, disciplining, makes, of, aziz, recoiled, neutralize,
# Nearest to than: counterweight, overgrowth, incomes, subsided, kcal, purley, couched, guilder,
# Nearest to some: onside, prolog, carolingian, noticeable, unnatural, percent, repetitions, landscapes,
# Nearest to system: branch, ietf, architectural, macsyma, systems, decker, circumpolar, holders,
# Nearest to egypt: ptolemaic, bordered, emsworth, stabat, ordered, vindhya, monotheists, abbasid,
# Nearest to recorded: dystopian, nails, protagonists, ozark, felis, messe, sediments, wailing,
# Nearest to paris: uneconomic, banished, netherlands, polonaise, vital, entered, quoque, plh,
# Nearest to magazine: muds, patti, forego, puts, mrl, frivolous, jermaine, nominee,
# Nearest to powers: vaginal, rests, mea, depraved, fukuyama, organise, westerner, lahore,
# Nearest to square: mathrm, diagonal, meadows, covers, km, foreground, spans, castles,
# Nearest to bbc: francks, manipulation, radio, corrected, throwback, icbm, disorganised, bhangra,
# Nearest to road: highway, chinatown, americanized, rail, stopwatch, building, phoebus, completed,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0407 0.0935 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0093 0.0930 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0080 0.0928 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0527 0.0920 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0912 0.0921 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0494 0.0921 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0686 0.0919 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1193 0.0914 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0568 0.0917 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0707 0.0920 sec/batch
# Nearest to such: concepts, purely, verrocchio, replicating, converges, consent, algebras, ccd,
# Nearest to eight: five, three, one, four, six, zero, two, guadeloupe,
# Nearest to at: concordant, lowers, pennock, hiram, unquestioning, manco, css, princeton,
# Nearest to zero: two, five, three, four, six, one, eight, nine,
# Nearest to from: drifting, the, makes, carducci, of, disciplining, acrylics, supports,
# Nearest to than: overgrowth, kcal, counterweight, incomes, subsided, couched, distinctions, horns,
# Nearest to some: prolog, onside, noticeable, unnatural, percent, carolingian, landscapes, unsettling,
# Nearest to system: branch, systems, ietf, architectural, efferent, combinatory, macsyma, circumpolar,
# Nearest to egypt: bordered, ptolemaic, stabat, emsworth, libya, seizes, vindhya, censuses,
# Nearest to recorded: nails, dystopian, protagonists, messe, ozark, vodun, lincom, felis,
# Nearest to paris: uneconomic, polonaise, netherlands, banished, quoque, vital, entered, doosra,
# Nearest to magazine: muds, patti, forego, archive, mrl, nominee, puts, frivolous,
# Nearest to powers: rests, vaginal, depraved, mea, fukuyama, westerner, sensory, lahore,
# Nearest to square: mathrm, diagonal, foreground, covers, spans, km, meadows, castles,
# Nearest to bbc: francks, manipulation, throwback, disorganised, radio, conversations, corrected, bhangra,
# Nearest to road: highway, chinatown, rail, americanized, stopwatch, building, phoebus, plaza,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0547 0.0930 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0714 0.0913 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0940 0.0912 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0507 0.0911 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0537 0.0907 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0640 0.0910 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0756 0.0907 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0522 0.0913 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0828 0.0912 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0653 0.0913 sec/batch
# Nearest to such: concepts, verrocchio, consent, purely, randal, associations, replicating, chromosphere,
# Nearest to eight: three, five, one, four, six, zero, two, seized,
# Nearest to at: concordant, hiram, manco, lowers, pennock, css, objectors, coronations,
# Nearest to zero: five, two, three, four, six, one, eight, nine,
# Nearest to from: drifting, the, of, disciplining, aziz, champagne, prague, expressed,
# Nearest to than: overgrowth, counterweight, subsided, kcal, couched, incomes, horns, purley,
# Nearest to some: onside, prolog, carolingian, unnatural, percent, repetitions, noticeable, landscapes,
# Nearest to system: branch, systems, decker, ietf, legislative, efferent, thereabouts, proposals,
# Nearest to egypt: ptolemaic, bordered, libya, emsworth, stabat, fundamentalists, vindhya, grunt,
# Nearest to recorded: nails, dystopian, protagonists, ozark, felis, behold, vodun, messe,
# Nearest to paris: polonaise, uneconomic, netherlands, entered, banished, vital, quoque, doosra,
# Nearest to magazine: muds, patti, archive, forego, mrl, puts, jermaine, nominee,
# Nearest to powers: rests, depraved, vaginal, legislative, fukuyama, abbas, wannsee, lahore,
# Nearest to square: mathrm, foreground, diagonal, covers, squares, meadows, avengers, castles,
# Nearest to bbc: francks, manipulation, conversations, throwback, bhangra, disorganised, corrected, radio,
# Nearest to road: highway, rail, chinatown, americanized, stopwatch, phoebus, immunization, winterfell,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0527 0.0934 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0451 0.0923 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0236 0.0921 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0932 0.0928 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0904 0.0914 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1075 0.0910 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1417 0.0910 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0330 0.0913 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0431 0.0916 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0717 0.0908 sec/batch
# Nearest to such: concepts, verrocchio, consent, purely, randal, associations, chromosphere, wane,
# Nearest to eight: three, four, one, five, six, zero, two, seized,
# Nearest to at: concordant, lowers, pennock, hiram, manco, fraser, leavenworth, six,
# Nearest to zero: two, five, three, four, six, one, eight, nine,
# Nearest to from: drifting, the, of, makes, disciplining, critias, disarming, supports,
# Nearest to than: incomes, counterweight, overgrowth, subsided, kcal, lackluster, couched, horns,
# Nearest to some: prolog, carolingian, onside, percent, unnatural, ensures, repetitions, noticeable,
# Nearest to system: branch, systems, macsyma, ietf, efferent, holders, combinatory, legislative,
# Nearest to egypt: bordered, ptolemaic, emsworth, libya, stabat, vindhya, ordered, grunt,
# Nearest to recorded: nails, dystopian, ozark, lincom, felis, protagonists, behold, bebop,
# Nearest to paris: polonaise, entered, uneconomic, quoque, banished, netherlands, doosra, vital,
# Nearest to magazine: muds, patti, forego, archive, mrl, demonstrator, puts, hail,
# Nearest to powers: rests, vaginal, depraved, westerner, sensory, diamagnets, mars, tinkering,
# Nearest to square: mathrm, diagonal, foreground, meadows, covers, squares, castles, annoyed,
# Nearest to bbc: francks, manipulation, conversations, bhangra, month, throwback, radio, disorganised,
# Nearest to road: highway, chinatown, rail, stopwatch, americanized, phoebus, routes, winterfell,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9828 0.0919 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0293 0.0914 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0386 0.0910 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0492 0.0908 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0767 0.0908 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0424 0.0874 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0185 0.0911 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9920 0.0906 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0196 0.0906 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9733 0.0909 sec/batch
# Nearest to such: concepts, consent, verrocchio, purely, randal, replicating, associations, artifact,
# Nearest to eight: one, three, four, five, six, zero, two, nine,
# Nearest to at: manco, hiram, concordant, pennock, lowers, leavenworth, overlooks, the,
# Nearest to zero: two, five, three, four, six, one, eight, nine,
# Nearest to from: the, drifting, of, supports, aziz, scientism, champagne, critias,
# Nearest to than: counterweight, overgrowth, incomes, subsided, purley, consonances, couched, distinctions,
# Nearest to some: prolog, onside, carolingian, unnatural, percent, ensures, autocephaly, noticeable,
# Nearest to system: branch, systems, macsyma, sepsis, architectural, efferent, combinatory, bidirectional,
# Nearest to egypt: ptolemaic, bordered, emsworth, libya, fundamentalists, chaldeans, grunt, ordered,
# Nearest to recorded: nails, ozark, felis, dystopian, behold, merodach, tooth, lincom,
# Nearest to paris: banished, entered, polonaise, quoque, uneconomic, netherlands, doosra, metz,
# Nearest to magazine: muds, patti, forego, archive, mrl, puts, demonstrator, stalker,
# Nearest to powers: rests, vaginal, depraved, westerner, sensory, abbas, wannsee, diamagnets,
# Nearest to square: mathrm, diagonal, castles, foreground, squares, meadows, covers, spans,
# Nearest to bbc: francks, bhangra, month, manipulation, day, conversations, corrected, throwback,
# Nearest to road: highway, chinatown, stopwatch, phoebus, immunization, routes, rail, winterfell,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9860 0.0916 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9592 0.0914 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0249 0.0908 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0410 0.0911 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0522 0.0919 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0121 0.0917 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9271 0.0914 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9565 0.0921 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9228 0.0921 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9885 0.0917 sec/batch
# Nearest to such: concepts, purely, verrocchio, consent, replicating, randal, chromosphere, associations,
# Nearest to eight: three, one, five, four, zero, six, two, nine,
# Nearest to at: lowers, pennock, manco, hiram, concordant, overlooks, balkline, pit,
# Nearest to zero: two, five, three, four, six, one, eight, nine,
# Nearest to from: the, drifting, of, supports, expressed, scientism, bromine, disarming,
# Nearest to than: counterweight, incomes, subsided, overgrowth, couched, purley, kcal, lackluster,
# Nearest to some: prolog, onside, carolingian, noticeable, unnatural, ensures, percent, unsettling,
# Nearest to system: branch, systems, legislative, sepsis, efferent, bolivar, architectural, macsyma,
# Nearest to egypt: ptolemaic, bordered, emsworth, libya, chaldeans, fundamentalists, musei, imparts,
# Nearest to recorded: nails, ozark, dystopian, behold, felis, tooth, goodwill, tuner,
# Nearest to paris: polonaise, banished, uneconomic, entered, quoque, netherlands, doosra, bern,
# Nearest to magazine: muds, patti, forego, archive, puts, mrl, frivolous, demonstrator,
# Nearest to powers: rests, vaginal, depraved, westerner, diamagnets, abbas, wannsee, mars,
# Nearest to square: mathrm, diagonal, squares, foreground, castles, spans, covers, meadows,
# Nearest to bbc: francks, bhangra, month, news, manipulation, airplay, throwback, corrected,
# Nearest to road: highway, chinatown, rail, phoebus, winterfell, immunization, building, completed,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9933 0.0926 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9860 0.0922 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9962 0.0919 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9933 0.0912 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0174 0.0909 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9308 0.0914 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0067 0.0919 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9753 0.0910 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0226 0.0917 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9921 0.0907 sec/batch
# Nearest to such: concepts, purely, randal, consent, replicating, chromosphere, associations, verrocchio,
# Nearest to eight: one, three, five, four, six, zero, two, nine,
# Nearest to at: concordant, pennock, manco, hiram, lowers, the, overlooks, balkline,
# Nearest to zero: two, five, three, four, six, one, eight, nine,
# Nearest to from: the, drifting, of, supports, expressed, carducci, makes, disarming,
# Nearest to than: counterweight, couched, incomes, distinctions, subsided, overgrowth, kcal, consonances,
# Nearest to some: onside, prolog, carolingian, unnatural, percent, weavers, noticeable, loach,
# Nearest to system: systems, branch, legislative, efferent, macsyma, sepsis, osa, circumpolar,
# Nearest to egypt: ptolemaic, bordered, libya, emsworth, ebrahim, khartoum, chaldeans, imparts,
# Nearest to recorded: nails, ozark, behold, felis, goodwill, regency, dystopian, tooth,
# Nearest to paris: polonaise, banished, entered, netherlands, uneconomic, quoque, doosra, bern,
# Nearest to magazine: muds, patti, puts, forego, archive, mrl, frivolous, interludes,
# Nearest to powers: rests, vaginal, diamagnets, depraved, westerner, lfloor, sensory, legislative,
# Nearest to square: mathrm, squares, diagonal, castles, foreground, annoyed, avengers, vargas,
# Nearest to bbc: francks, month, day, bhangra, airplay, corrected, throwback, pm,
# Nearest to road: highway, chinatown, toll, winterfell, cleverness, stopwatch, phoebus, immunization,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0023 0.0916 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9687 0.0912 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9844 0.0905 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0132 0.0906 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0249 0.0909 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0078 0.0909 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9810 0.0920 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9342 0.0922 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9988 0.0921 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0345 0.0923 sec/batch
# Nearest to such: concepts, purely, consent, randal, replicating, chromosphere, associations, verrocchio,
# Nearest to eight: three, one, four, five, six, zero, two, nine,
# Nearest to at: concordant, manco, hiram, pennock, overlooks, the, lowers, princeton,
# Nearest to zero: two, five, three, four, six, one, eight, nine,
# Nearest to from: the, of, drifting, supports, expressed, disarming, prague, makes,
# Nearest to than: incomes, couched, subsided, counterweight, overgrowth, consonances, kcal, earnings,
# Nearest to some: onside, prolog, carolingian, percent, loach, unnatural, landscapes, enrich,
# Nearest to system: systems, branch, legislative, efferent, macsyma, decker, sepsis, bolivar,
# Nearest to egypt: ptolemaic, bordered, libya, emsworth, claimed, ordered, ebrahim, islamists,
# Nearest to recorded: nails, ozark, felis, regency, sediments, behold, goodwill, tooth,
# Nearest to paris: polonaise, entered, uneconomic, banished, netherlands, quoque, doosra, bern,
# Nearest to magazine: muds, patti, puts, forego, mrl, frivolous, foster, archive,
# Nearest to powers: rests, vaginal, depraved, legislative, diamagnets, westerner, abbas, wannsee,
# Nearest to square: mathrm, castles, squares, diagonal, meadows, foreground, vargas, spans,
# Nearest to bbc: francks, day, month, bhangra, airplay, corrected, throwback, manipulation,
# Nearest to road: highway, chinatown, rail, stopwatch, toll, cleverness, immunization, phoebus,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9873 0.0927 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0831 0.0911 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0249 0.0913 sec/batch
# ...
# Nearest to eight: three, one, four, five, six, two, zero, nine,
# Nearest to at: the, six, an, only, over, leavenworth, pit, attained,
# Nearest to zero: two, five, three, six, four, one, nine, eight,
# Nearest to from: the, of, a, drifting, same, is, when, on,
# Nearest to than: fewer, incomes, couched, more, have, theobromine, consonances, kcal,
# Nearest to some: many, most, drowsiness, have, carolingian, include, onside, prolog,
# Nearest to system: systems, branch, legislative, efferent, bolivar, sepsis, goodwin, osa,
# Nearest to egypt: ptolemaic, generator, egyptian, ebrahim, disrupting, rhodium, libya, chaldeans,
# Nearest to recorded: nails, sediments, felis, cycles, concert, tooth, ascribed, during,
# Nearest to paris: uneconomic, france, seine, metz, polonaise, entered, experimentalists, banished,
# Nearest to magazine: muds, tapestry, patti, hail, puts, archive, bern, forego,
# Nearest to powers: legislative, telepathy, diamagnets, rests, wannsee, tinkering, giscard, westerner,
# Nearest to square: squares, castles, foreground, vargas, permeability, annoyed, risso, mathrm,
# Nearest to bbc: day, francks, pm, calendars, month, throwback, broadcasting, brythonic,
# Nearest to road: roads, highway, masts, chinatown, parklands, winterfell, toll, ronstadt,
# Epoch 8/10 Iteration: 34100 Avg. Training loss: 3.8558 0.0931 sec/batch
# Epoch 8/10 Iteration: 34200 Avg. Training loss: 3.8822 0.0918 sec/batch
# Epoch 8/10 Iteration: 34300 Avg. Training loss: 3.9074 0.0918 sec/batch
# Epoch 8/10 Iteration: 34400 Avg. Training loss: 3.8858 0.0914 sec/batch
# Epoch 8/10 Iteration: 34500 Avg. Training loss: 3.8846 0.0917 sec/batch
# Epoch 8/10 Iteration: 34600 Avg. Training loss: 3.8756 0.0919 sec/batch
# Epoch 8/10 Iteration: 34700 Avg. Training loss: 3.9077 0.0918 sec/batch
# Epoch 8/10 Iteration: 34800 Avg. Training loss: 3.9011 0.0914 sec/batch
# Epoch 8/10 Iteration: 34900 Avg. Training loss: 3.8959 0.0914 sec/batch
# Epoch 8/10 Iteration: 35000 Avg. Training loss: 3.8668 0.0914 sec/batch
# Nearest to such: other, also, concepts, purely, congregate, have, voucher, abramoff,
# Nearest to eight: three, one, five, four, six, two, nine, zero,
# Nearest to at: the, an, birthday, by, only, subs, pit, attained,
# Nearest to zero: two, five, three, four, six, one, nine, eight,
# Nearest to from: the, of, a, same, drifting, carducci, is, on,
# Nearest to than: incomes, fewer, couched, more, consonances, fallible, have, distinctions,
# Nearest to some: many, most, onside, carolingian, have, miles, drowsiness, loach,
# Nearest to system: systems, branch, legislative, bolivar, monolithic, goodwin, workgroup, efferent,
# Nearest to egypt: ptolemaic, egyptian, generator, ebrahim, rhodium, libya, disrupting, emsworth,
# Nearest to recorded: nails, recording, tour, during, cycles, concert, tooth, sediments,
# Nearest to paris: france, uneconomic, polonaise, entered, seine, experimentalists, metz, michel,
# Nearest to magazine: muds, tapestry, patti, hail, puts, bern, forego, archive,
# Nearest to powers: legislative, telepathy, rests, diamagnets, character, petitioner, lfloor, wannsee,
# Nearest to square: squares, annoyed, permeability, vargas, castles, foreground, hersh, mathrm,
# Nearest to bbc: day, pm, francks, calendars, month, brythonic, pleased, throwback,
# Nearest to road: roads, highway, masts, winterfell, toll, chinatown, parklands, ronstadt,
# Epoch 8/10 Iteration: 35100 Avg. Training loss: 3.9060 0.0929 sec/batch
# Epoch 8/10 Iteration: 35200 Avg. Training loss: 3.8920 0.0908 sec/batch
# Epoch 8/10 Iteration: 35300 Avg. Training loss: 3.8739 0.0913 sec/batch
# Epoch 8/10 Iteration: 35400 Avg. Training loss: 3.9078 0.0911 sec/batch
# Epoch 8/10 Iteration: 35500 Avg. Training loss: 3.8907 0.0913 sec/batch
# Epoch 8/10 Iteration: 35600 Avg. Training loss: 3.8531 0.0920 sec/batch
# Epoch 8/10 Iteration: 35700 Avg. Training loss: 3.8397 0.0920 sec/batch
# Epoch 8/10 Iteration: 35800 Avg. Training loss: 3.8445 0.0920 sec/batch
# Epoch 8/10 Iteration: 35900 Avg. Training loss: 3.8829 0.0924 sec/batch
# Epoch 8/10 Iteration: 36000 Avg. Training loss: 3.9115 0.0916 sec/batch
# Nearest to such: also, purely, concepts, congregate, have, other, zwingli, randal,
# Nearest to eight: three, one, six, five, four, nine, two, zero,
# Nearest to at: the, an, attended, subs, by, six, career, fifteen,
# Nearest to zero: two, five, three, six, four, one, nine, eight,
# Nearest to from: the, of, a, on, his, is, same, carducci,
# Nearest to than: incomes, fewer, couched, consonances, fallible, more, have, eurocheque,
# Nearest to some: many, loach, have, most, non, miles, carolingian, kermanshah,
# Nearest to system: systems, branch, legislative, monolithic, bolivar, sepsis, efferent, goodwin,
# Nearest to egypt: ptolemaic, generator, egyptian, rhodium, ebrahim, disrupting, luxor, emsworth,
# Nearest to recorded: nails, recording, ascribed, during, cycles, tour, sediments, felis,
# Nearest to paris: france, uneconomic, polonaise, experimentalists, seine, entered, metz, michel,
# Nearest to magazine: muds, tapestry, bern, patti, forego, hail, monthly, puts,
# Nearest to powers: telepathy, legislative, rests, diamagnets, realm, superhero, wannsee, hyksos,
# Nearest to square: squares, vargas, castles, permeability, coe, risso, annoyed, foreground,
# Nearest to bbc: day, francks, pm, calendars, gregorian, brythonic, month, have,
# Nearest to road: roads, highway, masts, toll, chinatown, parklands, ronstadt, winterfell,
# Epoch 8/10 Iteration: 36100 Avg. Training loss: 3.9419 0.0931 sec/batch
# Epoch 8/10 Iteration: 36200 Avg. Training loss: 3.9477 0.0919 sec/batch
# Epoch 8/10 Iteration: 36300 Avg. Training loss: 3.8682 0.0919 sec/batch
# Epoch 8/10 Iteration: 36400 Avg. Training loss: 3.8532 0.0919 sec/batch
# Epoch 8/10 Iteration: 36500 Avg. Training loss: 3.8652 0.0914 sec/batch
# Epoch 8/10 Iteration: 36600 Avg. Training loss: 3.8121 0.0917 sec/batch
# Epoch 8/10 Iteration: 36700 Avg. Training loss: 3.8884 0.0922 sec/batch
# Epoch 8/10 Iteration: 36800 Avg. Training loss: 3.8627 0.0913 sec/batch
# Epoch 8/10 Iteration: 36900 Avg. Training loss: 3.8659 0.0918 sec/batch
# Epoch 8/10 Iteration: 37000 Avg. Training loss: 3.8979 0.0912 sec/batch
# Nearest to such: also, concepts, other, have, for, purely, known, are,
# Nearest to eight: three, one, four, five, six, two, zero, nine,
# Nearest to at: the, an, attended, subs, only, attained, by, birthday,
# Nearest to zero: two, five, three, four, six, one, nine, eight,
# Nearest to from: the, of, a, on, same, into, is, drifting,
# Nearest to than: fewer, more, incomes, couched, consonances, have, fallible, poised,
# Nearest to some: many, have, most, loach, are, carolingian, drowsiness, non,
# Nearest to system: systems, branch, monolithic, legislative, specific, apple, workgroup, osa,
# Nearest to egypt: ptolemaic, egyptian, generator, rhodium, ebrahim, luxor, disrupting, libya,
# Nearest to recorded: nails, recording, slackware, tour, concert, dvd, cycles, felis,
# Nearest to paris: france, uneconomic, entered, polonaise, experimentalists, seine, metz, ephemerides,
# Nearest to magazine: muds, tapestry, patti, bern, forego, puts, hail, monthly,
# Nearest to powers: telepathy, legislative, superhero, rests, diamagnets, westerner, wannsee, tinkering,
# Nearest to square: squares, permeability, annoyed, vargas, castles, risso, foreground, cytoskeleton,
# Nearest to bbc: day, pm, francks, have, calendars, month, times, brythonic,
# Nearest to road: highway, roads, toll, masts, winterfell, parklands, ronstadt, chinatown,
# Epoch 9/10 Iteration: 37100 Avg. Training loss: 3.8940 0.0843 sec/batch
# Epoch 9/10 Iteration: 37200 Avg. Training loss: 3.8602 0.0909 sec/batch
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 3.8114 0.0905 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.8798 0.0905 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.7972 0.0909 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.8399 0.0908 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.8040 0.0912 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 3.8604 0.0909 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 3.8555 0.0910 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 3.8720 0.0916 sec/batch
# Nearest to such: also, congregate, concepts, purely, are, include, have, segmented,
# Nearest to eight: three, one, five, four, six, nine, two, zero,
# Nearest to at: the, an, only, by, attained, subs, attended, while,
# Nearest to zero: two, five, three, six, four, one, nine, eight,
# Nearest to from: the, of, a, on, into, is, when, same,
# Nearest to than: fewer, more, fallible, incomes, consonances, couched, have, theobromine,
# Nearest to some: many, most, have, are, carolingian, laren, drowsiness, there,
# Nearest to system: systems, branch, monolithic, legislative, sepsis, specific, bolivar, efferent,
# Nearest to egypt: ptolemaic, egyptian, rhodium, ebrahim, generator, luxor, libya, emsworth,
# Nearest to recorded: recording, nails, slackware, dvd, tour, ascribed, sessions, felis,
# Nearest to paris: france, uneconomic, experimentalists, entered, metz, seine, polonaise, michel,
# Nearest to magazine: muds, tapestry, patti, bern, puts, forego, mrl, monthly,
# Nearest to powers: telepathy, legislative, superhero, diamagnets, wannsee, westerner, hyksos, tinkering,
# Nearest to square: squares, castles, vargas, permeability, annoyed, risso, foreground, cytoskeleton,
# Nearest to bbc: day, pm, broadcasting, month, francks, throwback, calendars, have,
# Nearest to road: roads, highway, parklands, chinatown, toll, winterfell, masts, immunization,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8676 0.0928 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7727 0.0925 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8349 0.0928 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7740 0.0924 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8269 0.0916 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8448 0.0916 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8582 0.0918 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8502 0.0919 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8582 0.0916 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8879 0.0919 sec/batch
# Nearest to such: also, as, are, other, purely, for, have, include,
# Nearest to eight: three, one, four, six, five, two, nine, zero,
# Nearest to at: the, an, subs, only, six, pit, years, attained,
# Nearest to zero: two, five, three, four, six, one, nine, eight,
# Nearest to from: the, of, same, a, is, on, into, drifting,
# Nearest to than: more, have, fewer, incomes, consonances, less, theobromine, couched,
# Nearest to some: many, have, most, drowsiness, other, there, are, include,
# Nearest to system: systems, branch, monolithic, legislative, bolivar, goodwin, specific, osa,
# Nearest to egypt: ptolemaic, rhodium, ebrahim, generator, egyptian, libya, luxor, pondering,
# Nearest to recorded: nails, recording, slackware, cycles, felis, tour, sessions, sediments,
# Nearest to paris: france, seine, uneconomic, experimentalists, entered, metz, polonaise, michel,
# Nearest to magazine: muds, bern, tapestry, patti, monthly, hail, puts, forego,
# Nearest to powers: telepathy, legislative, westerner, superhero, hyksos, sovereign, wannsee, rests,
# Nearest to square: squares, castles, annoyed, permeability, vargas, foreground, risso, cytoskeleton,
# Nearest to bbc: day, pm, francks, broadcasting, throwback, month, calendars, pleased,
# Nearest to road: roads, toll, highway, parklands, chinatown, tomorrowland, masts, winterfell,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8469 0.0922 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8811 0.0918 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8332 0.0922 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8615 0.0922 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8720 0.0921 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8591 0.0913 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8568 0.0913 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8483 0.0917 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8891 0.0912 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8709 0.0910 sec/batch
# Nearest to such: also, as, purely, congregate, concepts, are, have, voucher,
# Nearest to eight: three, one, four, six, five, two, nine, zero,
# Nearest to at: the, an, six, years, by, over, subs, leavenworth,
# Nearest to zero: two, five, three, four, six, one, nine, eight,
# Nearest to from: the, of, a, into, is, same, on, carducci,
# Nearest to than: more, fewer, have, incomes, fallible, consonances, couched, less,
# Nearest to some: many, most, have, there, these, non, are, loach,
# Nearest to system: systems, branch, legislative, monolithic, bolivar, goodwin, panamsat, apart,
# Nearest to egypt: ptolemaic, luxor, egyptian, rhodium, generator, discusses, ebrahim, emsworth,
# Nearest to recorded: recording, nails, cycles, slackware, tour, ascribed, felis, locarno,
# Nearest to paris: france, seine, entered, experimentalists, uneconomic, metz, polonaise, dreyfus,
# Nearest to magazine: muds, bern, tapestry, puts, monthly, patti, bundeswehr, hail,
# Nearest to powers: legislative, telepathy, wannsee, superhero, character, realm, hyksos, commonwealth,
# Nearest to square: squares, castles, risso, annoyed, permeability, coe, cytoskeleton, accelerate,
# Nearest to bbc: day, pm, francks, throwback, broadcasting, brythonic, month, bhangra,
# Nearest to road: roads, highway, toll, immunization, tomorrowland, parklands, masts, chinatown,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8637 0.0924 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6d252857543a> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: expected bytes, NoneType found
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-19-0dcc3806116a> in <module>()
#       3
#       4 with tf.Session(graph=train_graph) as sess:
# ----> 5     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#       6     embed_mat = sess.run(embedding)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1437       return
#    1438     sess.run(self.saver_def.restore_op_name,
# -> 1439              {self.saver_def.filename_tensor_name: save_path})
#    1440
#    1441   @staticmethod
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# SystemError: <built-in function TF_Run> returned a result with an error set

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
